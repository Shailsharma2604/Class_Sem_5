# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , SimpleRNN

# %%
def generate_sequence_data(num_sequences, sequence_length):
    """Generates sequences of 
    Args:
        num_sequences: number of sequences to generate
        sequence_length: length of each sequence
    Returns:
        X: numpy array of shape (num_sequences, sequence_length, 1)
        y: numpy array of shape (num_sequences, 1)
    """
    Sequences=[]
    targets=[]
    for i in range(num_sequences):
        sequence = np.random.randint(0,10,size=sequence_length)
        target = sequence[-1]
        Sequences.append(sequence)
        targets.append(target)
    return np.array(Sequences), np.array(targets)

# Define hyperparameters
Sequence_length = 10
num_sequences = 1000
hidden_units = 32
epochs = 50

# Generate data
x_train, y_train = generate_sequence_data(num_sequences, Sequence_length)
x_test, y_test = generate_sequence_data(int(num_sequences*0.2), Sequence_length)

# reshape X to be [samples, time steps, features]
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# Build the model
model = Sequential()
model.add(SimpleRNN(hidden_units,activation='relu', input_shape=(Sequence_length, 1)))
model.add(Dense(1))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam' , metrics=['mae'])

# Train the model
model.fit(x_train, y_train, epochs=epochs, validation_data=(x_test, y_test))

# Evaluate the model
loss, mae = model.evaluate(x_test, y_test)
print("Mean Absolute Error: ", mae)
print("Loss: ", loss)

# Make predictions
predictions = model.predict(x_test)
print("Predictions: ", predictions)
# Out:
# Epoch 1/50
# C:\Users\shail sharma\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 5.1220 - mae: 1.8427 - val_loss: 2.0699 - val_mae: 1.2093
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5749 - mae: 1.0407 - val_loss: 0.4735 - val_mae: 0.5511
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2451 - mae: 0.3825 - val_loss: 0.0468 - val_mae: 0.1782
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0418 - mae: 0.1603 - val_loss: 0.0267 - val_mae: 0.1285
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - mae: 0.1038 - val_loss: 0.0135 - val_mae: 0.0940
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0124 - mae: 0.0860 - val_loss: 0.0136 - val_mae: 0.0901
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mae: 0.0744 - val_loss: 0.0068 - val_mae: 0.0632
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mae: 0.0587 - val_loss: 0.0055 - val_mae: 0.0556
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0519 - val_loss: 0.0045 - val_mae: 0.0538
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mae: 0.0475 - val_loss: 0.0030 - val_mae: 0.0421
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0411 - val_loss: 0.0024 - val_mae: 0.0363
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mae: 0.0347 - val_loss: 0.0026 - val_mae: 0.0400
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - mae: 0.0340 - val_loss: 0.0019 - val_mae: 0.0322
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0017 - val_mae: 0.0306
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mae: 0.0301 - val_loss: 0.0012 - val_mae: 0.0255
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - mae: 0.0288 - val_loss: 0.0010 - val_mae: 0.0236
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mae: 0.0249 - val_loss: 0.0014 - val_mae: 0.0283
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mae: 0.0269 - val_loss: 8.3259e-04 - val_mae: 0.0213
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0013e-04 - mae: 0.0230 - val_loss: 0.0010 - val_mae: 0.0247
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7204e-04 - mae: 0.0229 - val_loss: 0.0014 - val_mae: 0.0301
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mae: 0.0266 - val_loss: 6.0040e-04 - val_mae: 0.0178
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4569e-04 - mae: 0.0196 - val_loss: 6.6324e-04 - val_mae: 0.0195
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2039e-04 - mae: 0.0195 - val_loss: 8.0634e-04 - val_mae: 0.0221
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7897e-04 - mae: 0.0201 - val_loss: 4.9032e-04 - val_mae: 0.0163
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8174e-04 - mae: 0.0208 - val_loss: 4.8812e-04 - val_mae: 0.0172
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.
#  [ 3.0053456e+00]
#  [ 5.8895461e-03]
#  [ 2.0051997e+00]
#  [ 4.0092220e+00]
#  [ 3.9898021e+00]
#  [ 4.6964996e-03]
#  [ 5.9916534e+00]
#  [-3.4528859e-03]
#  [ 3.9951339e+00]
#  [ 6.0061502e+00]
#  [ 3.0002253e+00]
#  [ 7.9998832e+00]
#  [ 1.9809226e+00]
#  [ 8.0057364e+00]
#  [ 6.0108089e+00]
#  [ 3.0112448e+00]
#  [ 9.0068502e+00]
#  [ 9.0108395e+00]
#  [ 2.0058413e+00]
#  [ 4.9869175e+00]
#  [ 7.0084357e+00]
#  [ 3.0074489e+00]
#  [ 1.0110689e+00]
#  [ 3.0064831e+00]
#  [ 2.5218837e-03]
#  [ 8.0141277e+00]
#  [ 2.0121140e+00]
#  [ 6.0061193e+00]
#  [ 7.0075402e+00]
#  [ 8.9946299e+00]
#  [ 7.0072889e+00]
#  [ 1.9606483e+00]
#  [ 6.0419722e+00]
#  [ 3.5370514e-04]
#  [ 3.9890232e+00]
#  [ 4.0150852e+00]
#  [ 1.0151292e+00]
#  [ 5.9298389e-03]
#  [ 9.0115213e+00]
#  [ 5.0151844e+00]
#  [ 9.0058498e+00]
#  [ 7.0051966e+00]
#  [ 9.9735987e-01]
#  [ 9.0116863e+00]
#  [ 9.0107203e+00]
#  [ 2.0243311e+00]
#  [ 5.0008593e+00]
#  [ 7.0037394e+00]
#  [ 8.0085268e+00]
#  [ 9.0099840e+00]
#  [ 8.0118790e+00]
#  [ 9.0083256e+00]
#  [ 1.0077945e+00]
#  [ 9.9205196e-01]
#  [ 8.0036974e+00]
#  [ 3.9975650e+00]
#  [ 9.7982502e-01]
#  [ 9.0111055e+00]
#  [ 7.0126023e+00]
#  [ 6.9953685e+00]
#  [ 9.0080299e+00]
#  [ 6.0099635e+00]
#  [ 1.0031518e+00]
#  [ 9.9408233e-01]
#  [ 3.0058708e+00]
#  [ 1.9977108e+00]
#  [ 6.0109448e+00]
#  [ 5.9878907e+00]
#  [ 9.9906123e-01]
#  [ 5.9994407e+00]
#  [ 2.9922400e+00]
#  [ 7.0068326e+00]
#  [-3.5055764e-03]
#  [ 2.0016439e+00]
#  [ 9.0079927e+00]
#  [ 5.0095439e+00]
#  [ 7.0198064e+00]
#  [ 7.0091476e+00]
#  [-1.9065011e-02]
#  [ 6.0116920e+00]
#  [ 8.0130243e+00]
#  [ 1.0012838e+00]
#  [ 9.0068445e+00]
#  [ 9.9893868e-01]
#  [ 6.0148468e+00]
#  [ 3.9919522e+00]
#  [ 5.0474586e+00]
#  [ 5.0062985e+00]
#  [ 2.0064917e+00]
#  [ 6.0119514e+00]
#  [ 2.0074980e+00]
#  [ 6.0189888e-04]
#  [ 8.0061083e+00]
#  [-4.7768243e-03]
#  [ 4.0041094e+00]
#  [ 6.0064659e+00]
#  [ 2.9962184e+00]
#  [ 8.9969425e+00]
#  [ 7.0117803e+00]
#  [ 6.9919958e+00]
#  [ 2.0121539e+00]
#  [ 3.9956326e+00]
#  [ 9.0098934e+00]
#  [ 1.0047029e+00]
#  [ 3.9989126e+00]
#  [ 6.0016575e+00]
#  [ 9.0034695e+00]
#  [ 9.0091028e+00]
#  [ 5.0011907e+00]
#  [ 8.0033436e+00]
#  [-2.3141988e-03]
#  [ 1.0021731e+00]
#  [ 3.0074224e+00]
#  [ 8.0136099e+00]
#  [ 1.9971739e+00]
#  [ 1.0011486e+00]
#  [ 5.0024619e+00]
#  [ 6.0030217e+00]
#  [ 5.9962859e+00]
#  [ 8.0138865e+00]
#  [ 1.0016563e+00]
#  [ 4.0121808e+00]
#  [ 5.0132904e+00]
#  [ 7.0152111e+00]
#  [ 6.0051904e+00]
#  [ 4.0092158e+00]
#  [ 8.0121593e+00]
#  [ 2.0025992e+00]
#  [ 7.0136476e+00]
#  [ 3.0109293e+00]
#  [ 1.0040408e+00]
#  [ 3.0138938e+00]
#  [ 6.0060577e+00]
#  [ 9.0202618e+00]
#  [ 5.0052819e+00]
#  [ 6.0054393e+00]
#  [ 7.9952083e+00]
#  [ 8.0053663e+00]
#  [ 2.0124662e+00]
#  [ 5.0090599e+00]
#  [ 8.9949532e+00]
#  [ 8.0193729e+00]
#  [ 2.0055461e+00]
#  [ 7.0019245e+00]
#  [ 2.0038567e+00]
#  [ 3.9774599e+00]
#  [ 2.0033600e+00]
#  [ 6.0039577e+00]
#  [ 7.0174346e+00]
#  [-4.6950467e-03]
#  [ 4.0096807e+00]
#  [ 6.0131974e+00]
#  [ 9.0224857e+00]
#  [ 1.9943258e+00]
#  [ 1.0032517e+00]
#  [ 2.0061204e+00]
#  [ 2.0140064e+00]
#  [ 2.0104902e+00]
#  [ 8.0076389e+00]
#  [ 5.0015764e+00]
#  [ 2.0041656e+00]
#  [ 7.0122051e+00]
#  [ 8.0082083e+00]
#  [ 2.9947968e+00]
#  [ 7.1309917e-03]
#  [ 3.0068774e+00]
#  [ 3.0107415e+00]
#  [ 4.0042634e+00]
#  [ 3.9995015e+00]
#  [ 5.0078206e+00]
#  [ 9.9319828e-01]
#  [ 1.9970611e+00]
#  [-1.7956384e-03]
#  [ 8.0096941e+00]
#  [ 9.0108232e+00]
#  [ 4.0071058e+00]
#  [ 6.9983983e+00]
#  [ 1.9908751e+00]
#  [ 4.0027642e+00]
#  [ 6.0052490e+00]
#  [ 2.0047474e+00]
#  [ 2.0289619e+00]
#  [ 6.0095015e+00]
#  [ 6.0083132e+00]]
