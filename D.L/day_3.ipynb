# %% [markdown]
# # RNN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('RNN.csv')

# %%
data
# Out:
#    S.no  Lst year Fees  CGPA   Fees
# 0     1          10000   7.5  15000
# 1     2          20000   6.0  13000
# 2     3         100000   8.5  50000
# 3     4          65000   8.6  85750

# %%
x=data.drop('Fees',axis=1)
y=data['Fees']

# %%
x
# Out:
#    S.no  Lst year Fees  CGPA
# 0     1          10000   7.5
# 1     2          20000   6.0
# 2     3         100000   8.5
# 3     4          65000   8.6

# %%
y
# Out:
# 0    15000
# 1    13000
# 2    50000
# 3    85750
# Name: Fees, dtype: int64

# %%
scaler_x=MinMaxScaler()
scaler_y=MinMaxScaler()

# %%
x=scaler_x.fit_transform(x)
y=scaler_y.fit_transform(y.values.reshape(-1,1))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
timesteps=1
x_train=x_train.reshape(x_train.shape[0],timesteps,x_train.shape[1])
x_test=x_test.reshape(x_test.shape[0],timesteps,x_test.shape[1])

# %%
model=Sequential()
model.add(LSTM(100,activation='relu',input_shape=(x_train.shape[1],x_train.shape[2]),return_sequences=True))
model.add(Dropout(1))
# Out:
# C:\Users\shail sharma\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',loss='mse')
model.fit(x_train,y_train,epochs=100,batch_size=32,shuffle=False,validation_data=(x_test,y_test))
loss=model.evaluate(x_test,y_test)
print('Loss:',loss)
y_pred=model.predict(x_test)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 12/100
# ...

# %%
model.fit(x_train,y_train,epochs=100,batch_size=32,shuffle=False,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2752 - val_loss: 0.1670
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2751 - val_loss: 0.1670
# Epoch 12/100
# ...

# %%
loss=model.evaluate(x_test,y_test)
print('Loss:',loss)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1670
# Loss: 0.16696839034557343

# %%
y_pred=model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_pred = y_pred.reshape(-1, 1)
y_pred = scaler_y.inverse_transform(y_pred)
y_test = scaler_y.inverse_transform(y_test)

# %%
print('Predictions:',y_pred)
print('Real:',y_test)
# Out:
# Predictions: [[20824.791]
#  [20058.951]
#  [20755.275]
#  [20169.326]
#  [19863.941]
#  [20245.535]
#  [20316.396]
#  [20435.045]
#  [19753.598]
#  [20327.137]]
# Real: [[50000.]]
